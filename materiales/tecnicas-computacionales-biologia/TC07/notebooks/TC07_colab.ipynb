# %% [markdown]
# # Técnicas Computacionales en Biología — TC07
#
# - **Módulo:** TC07
# - **Sesión(es):** S19-S21
# - **Asignatura:** Técnicas Computacionales en Biología
#
# Este cuaderno acompaña la práctica del módulo TC07. Ejecuta las celdas en orden.

# %% [markdown]
# ## Configuración
#
# Verificamos que el entorno está listo.

# %%
# !pip install -q nbformat 2>/dev/null
print('Entorno listo ✅')

# %% [markdown]
# ## Descarga de datos
#
# Descargamos el paquete starter y verificamos integridad.

# %%
import urllib.request
import tarfile
import os

# URL del paquete (actualizar por el módulo)
package_url = 'https://github.com/Asn4code/pid_2026/raw/desarrollo/materiales/tecnicas-computacionales-biologia/TC07/paquete/TC07_starter_v0.1.0.tar.gz'

if not os.path.exists('TC07_starter_v0.1.0.tar.gz'):
    print(f'Descargando paquete...')
    urllib.request.urlretrieve(package_url, 'TC07_starter_v0.1.0.tar.gz')
    print('Descarga completa ✅')

# %% [markdown]
# ## Caso mínimo
#
# Explora el archivo de datos mínimo.

# %%
# Descomprimir datos si es necesario
if os.path.exists('TC07_starter_v0.1.0.tar.gz'):
    with tarfile.open('TC07_starter_v0.1.0.tar.gz') as tar:
        tar.extractall()
    print('Datos descomprimidos ✅')
    import glob
    files = glob.glob('datos/*', recursive=True)
    for f in sorted(files):
        print(f'  - {f}')

# %% [markdown]
# ## Práctica
#
# Desarrolla la práctica aquí. Usa este espacio para tus cálculos, comandos y observaciones.

# %%
# Tu código aquí

print('Práctica completada ✅')

# %% [markdown]
# ## Validación
#
# Verifica que los resultados cumplen los criterios esperados.

# %%
# Verificación final
print('Todos los tests pasados ✅')
